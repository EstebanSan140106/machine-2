# %% [markdown]
# <img src = "img/images.png" style="height:85px;">
#
# <div style="text-align:center">
#     Enero 20, 2025
#
#  # Pandas
#
#
# <img src ="img/Python-Logo.jpg" style="height:355px;">
#
# </div>
#
# *Esteban Sánchez*

# %% [markdown]
# ## 1. Pandas
#
# - Librería estándar de Python para datos tabulares.
# - Ofrece dos estructuras: Series (1-D) y DataFrame (2-D).

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## 2. Series
# - Vector + índice personalizable.
# - Se comporta como array de NumPy y como diccionario: se accede por posición o por etiqueta, se puede iterar, filtrar con mascaras, aplicar funciones de NumPy y castear a lista, array o dict.
# - Operaciones aritméticas alinean los índices; falta de coincidencia → NaN.

# %%
paises = pd.Series(['España' , 'Andorra' , 'Gibraltar' , 'Portugal' , 'Francia'])
print(paises)
# Out:
# 0       España
# 1      Andorra
# 2    Gibraltar
# 3     Portugal
# 4      Francia
# dtype: object

# %%
paises = pd.Series(['España' , 'Andorra' , 'Gibraltar' , 'Portugal' , 'Francia'],
                  index = range(10,60,10))
print(paises)
# Out:
# 10       España
# 20      Andorra
# 30    Gibraltar
# 40     Portugal
# 50      Francia
# dtype: object

# %%
ciudades = pd.Series(['Barcelona' , 'Madrid' , 'Valencia' , 'Sevilla'] , 
                    index =['a', 'b' , 'c' , 'd'])  #Especificando el indice
print(ciudades)
# Out:
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# dtype: object

# %%
ciudades.name = 'Ciudades con 2 equipos en primera división' #Nombre de Serie

ciudades.index.name = 'ID' #Nombre de la columna de indices 

print(ciudades)
# Out:
# ID
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# Name: Ciudades con 2 equipos en primera división, dtype: object

# %%
print (ciudades[2])
print (ciudades['c'])
print (ciudades['c'] == ciudades[2])
# Out:
# Valencia
# Valencia
# True
# C:\Users\USER\AppData\Local\Temp\ipykernel_20184\870621518.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print (ciudades[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_20184\870621518.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print (ciudades['c'] == ciudades[2])

# %% [markdown]
# ## 3. Comportamiento similar a ndarray

# %%
print(ciudades[ ['a','c'] ])
print(ciudades[ [0,3] ])
# Out:
# ID
# a    Barcelona
# c     Valencia
# Name: Ciudades con 2 equipos en primera división, dtype: object
# ID
# a    Barcelona
# d      Sevilla
# Name: Ciudades con 2 equipos en primera división, dtype: object
# C:\Users\USER\AppData\Local\Temp\ipykernel_20184\1121753603.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ciudades[ [0,3] ])

# %%
print(ciudades [:'c']) # incluye ambos extremos con el indice semantico
print(ciudades [:2])
# Out:
# ID
# a    Barcelona
# b       Madrid
# c     Valencia
# Name: Ciudades con 2 equipos en primera división, dtype: object
# ID
# a    Barcelona
# b       Madrid
# Name: Ciudades con 2 equipos en primera división, dtype: object

# %%
lista = list(ciudades[:'c'])

print(lista)
print(type(lista))
# Out:
# ['Barcelona', 'Madrid', 'Valencia']
# <class 'list'>

# %%
type(ciudades[:'c'])
# Out:
# pandas.core.series.Series

# %%
import numpy as np

ciudades_2 = np.array(ciudades[:'c'])
print(ciudades_2)
print(type(ciudades_2))
# Out:
# ['Barcelona' 'Madrid' 'Valencia']
# <class 'numpy.ndarray'>

# %%
lista = dict(ciudades[:'c'])
print(lista)
# Out:
# {'a': 'Barcelona', 'b': 'Madrid', 'c': 'Valencia'}

# %%
#uso de mask

fibonacci = pd.Series ([0,1,1,2,3,5,8,13,21])

print(fibonacci)

mask = fibonacci > 10
print(mask)
print(fibonacci[mask])

dst = pd.Series([13,21])

print(dst)
dst.equals(fibonacci)

fb = fibonacci[mask]

fb.reset_index(drop=True, inplace=True)

print(fb)

dst.equals(fb)
# Out:
# 0     0
# 1     1
# 2     1
# 3     2
# 4     3
# 5     5
# 6     8
# 7    13
# 8    21
# dtype: int64
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool
# 7    13
# 8    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# True

# %%
import numpy as np 

print(np.sum(fibonacci))
# Out:
# 54

# %%
#filtrar con np.where

distancias =pd.Series ([12.1,np.nan, 12.8,76.9,6.1,7.2])

distancias_validas = np.where(pd.notnull(distancias) , distancias,2)

print(distancias_validas)
print(type(distancias_validas))
# Out:
# [12.1  2.  12.8 76.9  6.1  7.2]
# <class 'numpy.ndarray'>

# %% [markdown]
# #### 3.0.1 Iteración

# %%
#iteracion sobre elemento

for value in fibonacci :
    print('Valor: ' + str(value))
for index in fibonacci.index:
    print('Indice: ' + str(index))
# Out:
# Valor: 0
# Valor: 1
# Valor: 1
# Valor: 2
# Valor: 3
# Valor: 5
# Valor: 8
# Valor: 13
# Valor: 21
# Indice: 0
# Indice: 1
# Indice: 2
# Indice: 3
# Indice: 4
# Indice: 5
# Indice: 6
# Indice: 7
# Indice: 8

# %%
for index , value in fibonacci.items():
    print('Índice:' + str(index) + ' Valor:' + str(value))
# Out:
# Índice:0 Valor:0
# Índice:1 Valor:1
# Índice:2 Valor:1
# Índice:3 Valor:2
# Índice:4 Valor:3
# Índice:5 Valor:5
# Índice:6 Valor:8
# Índice:7 Valor:13
# Índice:8 Valor:21

# %%
for index , value in zip(fibonacci.index , fibonacci):
    print('Índice:' + str(index) + ' Valor:' + str(value))
# Out:
# Índice:0 Valor:0
# Índice:1 Valor:1
# Índice:2 Valor:1
# Índice:3 Valor:2
# Índice:4 Valor:3
# Índice:5 Valor:5
# Índice:6 Valor:8
# Índice:7 Valor:13
# Índice:8 Valor:21

# %% [markdown]
# ### 3.1 Series como diccionarios
#
# - Interpreta al índice como clave
# - Acepta operaciones para diccionarios

# %%
# crear una serie a partir de un diccionario

serie = pd.Series({'Carlos' : 100 , 'Marcos' : 98})

print(serie.index)
print(serie.values)

print(serie)
print(type(serie))
# Out:
# Index(['Carlos', 'Marcos'], dtype='object')
# [100  98]
# Carlos    100
# Marcos     98
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
serie['Pedro'] = 12
serie ['Pedro'] = 15
del serie['Marcos']
print(serie)
# Out:
# Carlos    100
# Pedro      15
# dtype: int64

# %% [markdown]
# ### 3.2 Operaciones entre series

# %%
# suma de 2 series

#suma de valores con el mismo indice (NaN no aparece en ambas)
serie1 = pd.Series([10,20,30,40] , index =range(4) )
serie2 = pd.Series([1,2,3] , index =range(3) )

suma = serie1+ serie2
print(suma)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     NaN
# dtype: float64

# %%
print(serie1-serie2)
# Out:
# 0     9.0
# 1    18.0
# 2    27.0
# 3     NaN
# dtype: float64

# %%
result = serie1 + serie2

result[pd.isnull(result)] = 0 #mask con `isnull`
print(result)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     0.0
# dtype: float64

# %% [markdown]
# #### 3.2.1 Diferencias entre Pandas Series y diccionarios
# - Diccionario, es una estructura que relaciona las claves y los valores de forma arbitraria.
# -  Series, estructura de forma estricta listas de valores con listas de índice asignado en la posición.
# -  Series, es más eficiente para ciertas operaciones que los dicionarios.
# -  En las Series los valores de entrada pueden ser listas o Numpy arrays.
# -  En Series los índices semánticos pueden ser integers o caracteres, en los valores igual.
# -  Series se podría entender entre una lista y un diccionario Python, pero es de una dimensión

# %% [markdown]
# ## 4. DataFrame
# - Datos Tabulares (Fila x Columna)
# - Columnas: Series con índices compartidos

# %%
#añadir columnas

diccionario = {'Nombre' : ['Maria' , 'Laura' , 'Manuel'] ,
              "Edad" : [34,29,12] }
frame = pd.DataFrame (diccionario, index = ['a', 'b' , 'c'])
display(frame)
# Out:
#    Nombre  Edad
# a   Maria    34
# b   Laura    29
# c  Manuel    12

# %%
#ademas de 'index' el parametro 'columns' especifica el numero y orden de las columnas
frame = pd.DataFrame(diccionario , columns =['Nacionalidad' , 'Nombre' , 'Edad' , 'Profesion' , 'Genero'])
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion Genero
# 0          NaN   Maria    34       NaN    NaN
# 1          NaN   Laura    29       NaN    NaN
# 2          NaN  Manuel    12       NaN    NaN

# %%
#acceso a las columnas

nombres = frame['Nombre']
display(nombres)
print(type(nombres))

edad = frame ['Edad']
display(edad)
print(type(edad))
# Out:
# 0     Maria
# 1     Laura
# 2    Manuel
# Name: Nombre, dtype: object
# <class 'pandas.core.series.Series'>
# 0    34
# 1    29
# 2    12
# Name: Edad, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#siempre y cuando el nombre de la columna lo permita (espacios, ...=

nombres = frame.Profesion
display(nombres)
type(nombres)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: Profesion, dtype: object
# pandas.core.series.Series

# %%
print(frame['Nombre'][0])
print(frame.Nombre[0])
print(nombres[0])
# Out:
# Maria
# Maria
# nan

# %% [markdown]
# #### 4.0.1 Formas de crear un DataFrame
#
# - Serie de pandas
# - Lista de diccionarios
# - Diccionario de Serie Pandas
# - Con un array de Numpy bidimensional
# - Con un array de NumPy

# %% [markdown]
# ### 4.1 Modificar un DataFrame

# %%
# añadir columnas
diccionario = {"Nombre" : ["Maria" , "Laura" , "Daniel"] ,
              "Edad" : [34,29,12]}
frame = pd.DataFrame(diccionario, columns = ['Nacionalidad' , 'Nombre' , 'Edad' , 'Profesion' , 'Direccion'])
frame ['Direccion'] = 'Desconocida'
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion    Direccion
# 0          NaN   Maria    34       NaN  Desconocida
# 1          NaN   Laura    29       NaN  Desconocida
# 2          NaN  Daniel    12       NaN  Desconocida

# %%
lista_direcciones = ['Rue 13 del Percebe, 13', 'Evergreen Terrace, 3', 'Av de los Rombos, 12']

# %%
frame['Direccion'] = lista_direcciones

display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN   Maria    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Daniel    12       NaN    Av de los Rombos, 12

# %%
#añadir una fila
user_2  = ['Alemania' , 'Klaus' , 20, 'none' , 'Desconocida']

frame.loc[3] = user_2
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN   Maria    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Daniel    12       NaN    Av de los Rombos, 12
# 3     Alemania   Klaus    20      none             Desconocida

# %%
frame = pd.DataFrame(diccionario , columns =['Nacionalidad' , 'Nombre' , 'Edad',  'Profesion'])

frame = frame.drop(2)
display(frame)

frame.drop('Nombre' , axis=1, inplace=True)
display(frame)
# Out:
#   Nacionalidad Nombre  Edad Profesion
# 0          NaN  Maria    34       NaN
# 1          NaN  Laura    29       NaN
#   Nacionalidad  Edad Profesion
# 0          NaN    34       NaN
# 1          NaN    29       NaN

# %%
#elimiar columna

del frame['Profesion']
display(frame)
# Out:
#   Nacionalidad  Edad
# 0          NaN    34
# 1          NaN    29

# %%
display(frame.T)
# Out:
#                 0    1
# Nacionalidad  NaN  NaN
# Edad           34   29

# %% [markdown]
# ### 4.2 Iteración

# %%
frame = pd.DataFrame(diccionario, columns = ['Nacionalidad' , 'Nombre' , 'Edad' , 'Profesion'])
display(frame)

for a in frame :
    print(a)
    print(type(a))
# Out:
#   Nacionalidad  Nombre  Edad Profesion
# 0          NaN   Maria    34       NaN
# 1          NaN   Laura    29       NaN
# 2          NaN  Daniel    12       NaN
# Nacionalidad
# <class 'str'>
# Nombre
# <class 'str'>
# Edad
# <class 'str'>
# Profesion
# <class 'str'>

# %%
# iteracion sobre filas
for value in frame.values:
    print(value)
    print(type(value))
# Out:
# [nan 'Maria' 34 nan]
# <class 'numpy.ndarray'>
# [nan 'Laura' 29 nan]
# <class 'numpy.ndarray'>
# [nan 'Daniel' 12 nan]
# <class 'numpy.ndarray'>

# %%
# iterar sobre filas y leugo sobre cada valor
for values in frame.values:
    for value in values:
        print(value)
# Out:
# nan
# Maria
# 34
# nan
# nan
# Laura
# 29
# nan
# nan
# Daniel
# 12
# nan

# %% [markdown]
# Repositorio en GitHub: https://github.com/EstebanSan140106/machine-2.git
